# %%
import numpy as np
import matplotlib.pyplot as plot
from scipy import misc

# %%
racoon = misc.face()

# %%
racoon.shape,racoon.size
# Out:
# ((768, 1024, 3), 2359296)

# %%
plot.imshow(racoon);

# %%
racoon[0,0]
# Out:
# array([121, 112, 131], dtype=uint8)

# %%
racoon[767,0]
# Out:
# array([ 85, 101,  74], dtype=uint8)

# %%
img1 = racoon[:500,400:850]

# %%
plot.imshow(img1);

# %%
img2 = img1.copy()

# %%
img2[:,:,0:2] = 0

# %%
plot.imshow(img2);

# %%
racooncopy = racoon.copy()
racooncopy[:,:,:1] = racooncopy[:,:,1:2]
plot.imshow(racooncopy);

# %%
img3 = misc.ascent()

# %%
img3.shape
# Out:
# (512, 512)

# %%
plot.imshow(img3);
