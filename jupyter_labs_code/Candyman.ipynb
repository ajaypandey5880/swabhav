# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('candy.csv')
df
# Out:
#                                          item             user  review
# 0       Reese's Peanut Butter Cups Miniatures        darlene90       5
# 1       Reese's Peanut Butter Cups Miniatures    taylordarlene       4
# 2       Reese's Peanut Butter Cups Miniatures     aliciadennis       5
# 3       Reese's Peanut Butter Cups Miniatures            ocook       5
# 4       Reese's Peanut Butter Cups Miniatures           chad38       5
# ...                                       ...              ...     ...
# 17229  Hershey's Nuggets Chocolate Assortment       acostanoah       5
# 17230  Hershey's Nuggets Chocolate Assortment        jeffrey01       5
# 17231  Hershey's Nuggets Chocolate Assortment      powellmegan       5
# 17232  Hershey's Nuggets Chocolate Assortment  benjaminjohnson       5
# 17233  Hershey's Nuggets Chocolate Assortment        xrichards       5
#
# [17234 rows x 3 columns]

# %%
df.describe()
# Out:
#              review
# count  17234.000000
# mean       4.590345
# std        0.858525
# min        1.000000
# 25%        5.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17234 entries, 0 to 17233
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   item    17234 non-null  object
#  1   user    17234 non-null  object
#  2   review  17234 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 404.0+ KB

# %%
df.item.unique
# Out:
# <bound method Series.unique of 0         Reese's Peanut Butter Cups Miniatures
# 1         Reese's Peanut Butter Cups Miniatures
# 2         Reese's Peanut Butter Cups Miniatures
# 3         Reese's Peanut Butter Cups Miniatures
# 4         Reese's Peanut Butter Cups Miniatures
#                           ...
# 17229    Hershey's Nuggets Chocolate Assortment
# 17230    Hershey's Nuggets Chocolate Assortment
# 17231    Hershey's Nuggets Chocolate Assortment
# 17232    Hershey's Nuggets Chocolate Assortment
# 17233    Hershey's Nuggets Chocolate Assortment
# Name: item, Length: 17234, dtype: object>

# %%
df.user.unique
# Out:
# <bound method Series.unique of 0              darlene90
# 1          taylordarlene
# 2           aliciadennis
# 3                  ocook
# 4                 chad38
#               ...
# 17229         acostanoah
# 17230          jeffrey01
# 17231        powellmegan
# 17232    benjaminjohnson
# 17233          xrichards
# Name: user, Length: 17234, dtype: object>

# %%
pd.DataFrame(df,columns=df.item,index=df.user)
# Out:
# item             Reese's Peanut Butter Cups Miniatures  \
# user
# darlene90                                          NaN
# taylordarlene                                      NaN
# aliciadennis                                       NaN
# ocook                                              NaN
# chad38                                             NaN
# ...                                                ...
# acostanoah                                         NaN
# jeffrey01                                          NaN
# powellmegan                                        NaN
# benjaminjohnson                                    NaN
# xrichards                                          NaN
#
# item             Reese's Peanut Butter Cups Miniatures  \
# user
# darlene90                                          NaN
# taylordarlene                                      NaN
# aliciadennis                                       NaN
# ocook                                              NaN
# ...
