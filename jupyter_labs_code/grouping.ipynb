# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('marks_frame.csv')
df.columns = ['name','subject','marks']
df
# Out:
#            name subject  marks
# 0       Harshit  Python   95.0
# 1       Vaibhav    Java   80.0
# 2        Nitesh       C   90.0
# 3      Kartikey    HTML   98.0
# 4         Kunal    Java   60.0
# 5  Venkateshwar  Python   70.0
# 6        Akshay  Python    NaN
# 7       Ratnesh     NaN   60.0

# %%
df.sort_values(by='name',ascending=False)
# Out:
#            name subject  marks
# 5  Venkateshwar  Python   70.0
# 1       Vaibhav    Java   80.0
# 7       Ratnesh     NaN   60.0
# 2        Nitesh       C   90.0
# 4         Kunal    Java   60.0
# 3      Kartikey    HTML   98.0
# 0       Harshit  Python   95.0
# 6        Akshay  Python    NaN

# %%
df.sort_values(['name','marks'])
# Out:
#            name subject  marks
# 6        Akshay  Python    NaN
# 0       Harshit  Python   95.0
# 3      Kartikey    HTML   98.0
# 4         Kunal    Java   60.0
# 2        Nitesh       C   90.0
# 7       Ratnesh     NaN   60.0
# 1       Vaibhav    Java   80.0
# 5  Venkateshwar  Python   70.0

# %%
df.subject.sort_values()
# Out:
# 2         C
# 3      HTML
# 1      Java
# 4      Java
# 0    Python
# 5    Python
# 6    Python
# 7       NaN
# Name: subject, dtype: object

# %%
df.sort_index(ascending=False)
# Out:
#            name subject  marks
# 7       Ratnesh     NaN   60.0
# 6        Akshay  Python    NaN
# 5  Venkateshwar  Python   70.0
# 4         Kunal    Java   60.0
# 3      Kartikey    HTML   98.0
# 2        Nitesh       C   90.0
# 1       Vaibhav    Java   80.0
# 0       Harshit  Python   95.0

# %%
df.rename(columns={'name':'fname'})
# Out:
#           fname subject  marks
# 0       Harshit  Python   95.0
# 1       Vaibhav    Java   80.0
# 2        Nitesh       C   90.0
# 3      Kartikey    HTML   98.0
# 4         Kunal    Java   60.0
# 5  Venkateshwar  Python   70.0
# 6        Akshay  Python    NaN
# 7       Ratnesh     NaN   60.0

# %%
df.set_index('name')
# Out:
#              subject  marks
# name
# Harshit       Python   95.0
# Vaibhav         Java   80.0
# Nitesh             C   90.0
# Kartikey        HTML   98.0
# Kunal           Java   60.0
# Venkateshwar  Python   70.0
# Akshay        Python    NaN
# Ratnesh          NaN   60.0

# %%
df
# Out:
#            name subject  marks
# 0       Harshit  Python   95.0
# 1       Vaibhav    Java   80.0
# 2        Nitesh       C   90.0
# 3      Kartikey    HTML   98.0
# 4         Kunal    Java   60.0
# 5  Venkateshwar  Python   70.0
# 6        Akshay  Python    NaN
# 7       Ratnesh     NaN   60.0

# %%
import seaborn as sns

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'tips', 'titanic']

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.groupby(by='day')

# %%
df.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
grp = df.groupby(by='day')

# %%
grp.size()
# Out:
# day
# Thur    62
# Fri     19
# Sat     87
# Sun     76
# dtype: int64

# %%
for n,d in grp:
    print(type(n),type(d))
# Out:
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>

# %%
grp.count()
# Out:
#       total_bill  tip  sex  smoker  time  size
# day
# Thur          62   62   62      62    62    62
# Fri           19   19   19      19    19    19
# Sat           87   87   87      87    87    87
# Sun           76   76   76      76    76    76

# %%
grp.total_bill.sum()
# Out:
# day
# Thur    1096.33
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Name: total_bill, dtype: float64

# %%
df.groupby('sex')[['total_bill','tip']].sum()
# Out:
#         total_bill     tip
# sex
# Male       3256.82  485.07
# Female     1570.95  246.51

# %%
df.groupby('sex')['total_bill'].count()
# Out:
# sex
# Male      157
# Female     87
# Name: total_bill, dtype: int64

# %%
df.groupby(by='day')[['total_bill']].agg(['sum','mean','count'])
# Out:
#      total_bill
#             sum       mean count
# day
# Thur    1096.33  17.682742    62
# Fri      325.88  17.151579    19
# Sat     1778.40  20.441379    87
# Sun     1627.16  21.410000    76

# %%
df.groupby(by=['day','sex']).tip.count()
# Out:
# day   sex
# Thur  Male      30
#       Female    32
# Fri   Male      10
#       Female     9
# Sat   Male      59
#       Female    28
# Sun   Male      58
#       Female    18
# Name: tip, dtype: int64

# %%
df.groupby(by=['day','sex']).tip.mean()
# Out:
# day   sex
# Thur  Male      2.980333
#       Female    2.575625
# Fri   Male      2.693000
#       Female    2.781111
# Sat   Male      3.083898
#       Female    2.801786
# Sun   Male      3.220345
#       Female    3.367222
# Name: tip, dtype: float64

# %%
df['tip_per'] = df.tip/df.total_bill*100

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size    tip_per
# 0         16.99  1.01  Female     No   Sun  Dinner     2   5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3  16.054159
# 2         21.01  3.50    Male     No   Sun  Dinner     3  16.658734
# 3         23.68  3.31    Male     No   Sun  Dinner     2  13.978041
# 4         24.59  3.61  Female     No   Sun  Dinner     4  14.680765
# ..          ...   ...     ...    ...   ...     ...   ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  20.392697
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   7.358352
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   8.822232
# 242       17.82  1.75    Male     No   Sat  Dinner     2   9.820426
# 243       18.78  3.00  Female     No  Thur  Dinner     2  15.974441
#
# [244 rows x 8 columns]

# %%
df.groupby(by='sex').tip_per.mean()
# Out:
# sex
# Male      15.765055
# Female    16.649074
# Name: tip_per, dtype: float64
