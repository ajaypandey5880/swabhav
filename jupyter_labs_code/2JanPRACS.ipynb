# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
candidatesData = pd.read_csv("Candidates.csv")
electorsData = pd.read_csv("Electors.csv")

# %%
candidatesData
# Out:
#      ST_CODE      State_name  Month  Year  PC_Number     PC_name PC_Type  \
# 0        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 1        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 2        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 3        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# 4        S01  Andhra Pradesh      3  2009          1    Adilabad      ST
# ...      ...             ...    ...   ...        ...         ...     ...
# 8065     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8066     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8067     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8068     U07      Puducherry      3  2009          1  Puducherry     GEN
# 8069     U07      Puducherry      3  2009          1  Puducherry     GEN
#
#               Candidate_Name Candidate_Sex Candidate_Category  Candidate_Age  \
# ...

# %%
sns.countplot(data=candidatesData,x=candidatesData.Candidate_Sex,hue=candidatesData.Candidate_Category)
# Out:
# <AxesSubplot:xlabel='Candidate_Sex', ylabel='count'>

# %%
candidatesData.Candidate_Age.hist()
# Out:
# <AxesSubplot:>

# %%
candidatesData.Position.hist()
# Out:
# <AxesSubplot:>

# %%
candidatesData.Candidate_Age.corr(other=candidatesData.Position)
# Out:
# -0.2094963158258293

# %%
plt.figure(figsize=(15,5))
sns.histplot(data= candidatesData,x=candidatesData.Position,y=candidatesData.Candidate_Age,hue=candidatesData.Candidate_Sex)
# Out:
# <AxesSubplot:xlabel='Position', ylabel='Candidate_Age'>

# %%
plt.figure(figsize=(15,15))
sns.barplot(data=candidatesData,y=candidatesData.Party_Abbreviation,x=candidatesData.Total_Votes_Polled,
            ci=False,estimator=np.mean)
# Out:
# <AxesSubplot:xlabel='Total_Votes_Polled', ylabel='Party_Abbreviation'>

# %%
candidatesData.Party_Abbreviation.describe()
# Out:
# count     8070
# unique     363
# top        IND
# freq      3850
# Name: Party_Abbreviation, dtype: object

# %%
candidatesData.Total_Votes_Polled.describe()
# Out:
# count      8070.000000
# mean      51708.935343
# std      109718.351784
# min         118.000000
# 25%        1625.000000
# 50%        4101.500000
# 75%       18557.000000
# max      832224.000000
# Name: Total_Votes_Polled, dtype: float64
