# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("marks_frame.csv", header=None)
df
# Out:
#               0       1     2
# 0        Saurav    Java  90.0
# 1       Harshit  Python  95.0
# 2       Vaibhav    Java  80.0
# 3        Nitesh       C  90.0
# 4      Kartikey    HTML  98.0
# 5         Kunal    Java  60.0
# 6  Venkateshwar  Python  70.0
# 7        Akshay  Python   NaN
# 8       Ratnesh     NaN  60.0

# %%
df.columns = ['Name','Subject','Marks']

# %%
df
# Out:
#            Name Subject  Marks
# 0        Saurav    Java   90.0
# 1       Harshit  Python   95.0
# 2       Vaibhav    Java   80.0
# 3        Nitesh       C   90.0
# 4      Kartikey    HTML   98.0
# 5         Kunal    Java   60.0
# 6  Venkateshwar  Python   70.0
# 7        Akshay  Python    NaN
# 8       Ratnesh     NaN   60.0

# %%
df.columns,df.index,df.dtypes
# Out:
# (Index(['Name', 'Subject', 'Marks'], dtype='object'),
#  RangeIndex(start=0, stop=9, step=1),
#  Name        object
#  Subject     object
#  Marks      float64
#  dtype: object)

# %%
df['Marks'].dtype
# Out:
# dtype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     9 non-null      object
#  1   Subject  8 non-null      object
#  2   Marks    8 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 344.0+ bytes

# %%
df.isnull().any()
# Out:
# Name       False
# Subject     True
# Marks       True
# dtype: bool

# %%
df.describe()
# Out:
#          Marks
# count   8.0000
# mean   80.3750
# std    15.3431
# min    60.0000
# 25%    67.5000
# 50%    85.0000
# 75%    91.2500
# max    98.0000

# %%
type(df[['Name','Subject']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Name','Subject']]
# Out:
#            Name Subject
# 0        Saurav    Java
# 1       Harshit  Python
# 2       Vaibhav    Java
# 3        Nitesh       C
# 4      Kartikey    HTML
# 5         Kunal    Java
# 6  Venkateshwar  Python
# 7        Akshay  Python
# 8       Ratnesh     NaN

# %% [markdown]
# # Slicing

# %%
df[0:2]
# Out:
#       Name Subject  Marks
# 0   Saurav    Java   90.0
# 1  Harshit  Python   95.0

# %%
df.iloc[0:2]
# Out:
#       Name Subject  Marks
# 0   Saurav    Java   90.0
# 1  Harshit  Python   95.0

# %%
df.loc[0:2]
# Out:
#       Name Subject  Marks
# 0   Saurav    Java   90.0
# 1  Harshit  Python   95.0
# 2  Vaibhav    Java   80.0

# %%
df.iloc[-2:]
# Out:
#       Name Subject  Marks
# 7   Akshay  Python    NaN
# 8  Ratnesh     NaN   60.0

# %%
df.iloc[:2,:2]
# Out:
#       Name Subject
# 0   Saurav    Java
# 1  Harshit  Python

# %%
df.loc[:2,['Name','Subject']]
# Out:
#       Name Subject
# 0   Saurav    Java
# 1  Harshit  Python
# 2  Vaibhav    Java

# %%
df.loc[3:5,['Subject','Marks']]
# Out:
#   Subject  Marks
# 3       C   90.0
# 4    HTML   98.0
# 5    Java   60.0

# %%
df['Name'] == 'Nitesh'
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# Name: Name, dtype: bool

# %%
df['Subject'].value_counts()
# Out:
# Java      3
# Python    3
# C         1
# HTML      1
# Name: Subject, dtype: int64

# %%
df = pd.read_json("https://restcountries.eu/rest/v2/all")
df
# Out:
#                   name topLevelDomain alpha2Code alpha3Code callingCodes  \
# 0          Afghanistan          [.af]         AF        AFG         [93]
# 1        Åland Islands          [.ax]         AX        ALA        [358]
# 2              Albania          [.al]         AL        ALB        [355]
# 3              Algeria          [.dz]         DZ        DZA        [213]
# 4       American Samoa          [.as]         AS        ASM       [1684]
# ..                 ...            ...        ...        ...          ...
# 245  Wallis and Futuna          [.wf]         WF        WLF        [681]
# 246     Western Sahara          [.eh]         EH        ESH        [212]
# 247              Yemen          [.ye]         YE        YEM        [967]
# 248             Zambia          [.zm]         ZM        ZMB        [260]
# 249           Zimbabwe          [.zw]         ZW        ZWE        [263]
#
#        capital                                       altSpellings   region  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            250 non-null    object
#  1   topLevelDomain  250 non-null    object
#  2   alpha2Code      250 non-null    object
#  3   alpha3Code      250 non-null    object
#  4   callingCodes    250 non-null    object
#  5   capital         250 non-null    object
#  6   altSpellings    250 non-null    object
#  7   region          250 non-null    object
#  8   subregion       250 non-null    object
#  9   population      250 non-null    int64
#  10  latlng          250 non-null    object
#  11  demonym         250 non-null    object
#  12  area            240 non-null    float64
#  13  gini            153 non-null    float64
#  14  timezones       250 non-null    object
#  15  borders         250 non-null    object
#  16  nativeName      250 non-null    object
# ...

# %%
df.isnull().any()
# Out:
# name              False
# topLevelDomain    False
# alpha2Code        False
# alpha3Code        False
# callingCodes      False
# capital           False
# altSpellings      False
# region            False
# subregion         False
# population        False
# latlng            False
# demonym           False
# area               True
# gini               True
# timezones         False
# borders           False
# nativeName        False
# numericCode        True
# currencies        False
# languages         False
# translations      False
# flag              False
# regionalBlocs     False
# cioc               True
# dtype: bool

# %%
df[df['name'] == 'India']
# Out:
#       name topLevelDomain alpha2Code alpha3Code callingCodes    capital  \
# 104  India          [.in]         IN        IND         [91]  New Delhi
#
#                                          altSpellings region      subregion  \
# 104  [IN, Bhārat, Republic of India, Bharat Ganrajya]   Asia  Southern Asia
#
#      population  ...    timezones                                   borders  \
# 104  1295210000  ...  [UTC+05:30]  [AFG, BGD, BTN, MMR, CHN, NPL, PAK, LKA]
#
#      nativeName  numericCode  \
# 104        भारत        356.0
#
#                                             currencies  \
# 104  [{'code': 'INR', 'name': 'Indian rupee', 'symb...
#
#                                              languages  \
# 104  [{'iso639_1': 'hi', 'iso639_2': 'hin', 'name':...
#
#                                           translations  \
# 104  {'de': 'Indien', 'es': 'India', 'fr': 'Inde', ...
#
#                                       flag  \
# 104  https://restcountries.eu/data/ind.svg
#
# ...

# %%
df.iloc[104]
# Out:
# name                                                          India
# topLevelDomain                                                [.in]
# alpha2Code                                                       IN
# alpha3Code                                                      IND
# callingCodes                                                   [91]
# capital                                                   New Delhi
# altSpellings       [IN, Bhārat, Republic of India, Bharat Ganrajya]
# region                                                         Asia
# subregion                                             Southern Asia
# population                                               1295210000
# latlng                                                 [20.0, 77.0]
# demonym                                                      Indian
# area                                                    3.28759e+06
# gini                                                           33.4
# ...

# %%
df = pd.read_csv('../data/emp_data.csv')

# %%
df.columns = ['EmpNo','Name','Job','MgrId','DOJ','Sal','Comm','DeptNo']

# %%
df
# Out:
#     EmpNo      Name          Job   MgrId          DOJ   Sal    Comm  DeptNo
# 0    7369   'SMITH'      'CLERK'  7902.0  '17-DEC-80'   800     NaN      20
# 1    7788   'SCOTT'    'ANALYST'  7566.0  '09-DEC-82'  3000     NaN      20
# 2    7934  'MILLER'      'CLERK'  7782.0  '23-JAN-82'  1300     NaN      10
# 3    7654  'MARTIN'   'SALESMAN'  7698.0  '28-SEP-81'  1250  1400.0      30
# 4    7499   'ALLEN'   'SALESMAN'  7698.0  '20-FEB-81'  1600   300.0      30
# 5    7839    'KING'  'PRESIDENT'     NaN  '17-NOV-81'  5000     NaN      10
# 6    7782   'CLARK'    'MANAGER'  7839.0   '9-JUN-81'  2450     NaN      10
# 7    7844  'TURNER'   'SALESMAN'  7698.0   '8-SEP-81'  1500     0.0      30
# 8    7900   'JAMES'      'CLERK'  7698.0   '3-DEC-81'   950     NaN      30
# 9    7521    'WARD'   'SALESMAN'  7698.0  '22-FEB-81'  1250   500.0      30
# 10   7902    'FORD'    'ANALYST'  7566.0   '3-DEC-81'  3000     NaN      20
# ...

# %%
df[df.duplicated()]
# Out:
#     EmpNo      Name          Job   MgrId          DOJ   Sal    Comm  DeptNo
# 14   7369   'SMITH'      'CLERK'  7902.0  '17-DEC-80'   800     NaN      20
# 15   7788   'SCOTT'    'ANALYST'  7566.0  '09-DEC-82'  3000     NaN      20
# 16   7654  'MARTIN'   'SALESMAN'  7698.0  '28-SEP-81'  1250  1400.0      30
# 17   7499   'ALLEN'   'SALESMAN'  7698.0  '20-FEB-81'  1600   300.0      30
# 18   7839    'KING'  'PRESIDENT'     NaN  '17-NOV-81'  5000     NaN      10
# 19   7782   'CLARK'    'MANAGER'  7839.0   '9-JUN-81'  2450     NaN      10
# 20   7844  'TURNER'   'SALESMAN'  7698.0   '8-SEP-81'  1500     0.0      30
# 21   7900   'JAMES'      'CLERK'  7698.0   '3-DEC-81'   950     NaN      30

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   EmpNo   22 non-null     int64
#  1   Name    22 non-null     object
#  2   Job     22 non-null     object
#  3   MgrId   20 non-null     float64
#  4   DOJ     22 non-null     object
#  5   Sal     22 non-null     int64
#  6   Comm    7 non-null      float64
#  7   DeptNo  22 non-null     int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 1.5+ KB

# %%
df.drop_duplicates(inplace = True)

# %%
df.isnull().any()
# Out:
# EmpNo     False
# Name      False
# Job       False
# MgrId      True
# DOJ       False
# Sal       False
# Comm       True
# DeptNo    False
# dtype: bool

# %%
df[df['Comm'].isnull()][['Name','Sal']]
# Out:
#         Name   Sal
# 0    'SMITH'   800
# 1    'SCOTT'  3000
# 2   'MILLER'  1300
# 5     'KING'  5000
# 6    'CLARK'  2450
# 8    'JAMES'   950
# 10    'FORD'  3000
# 11   'ADAMS'  1100
# 12   'JONES'  2975
# 13   'BLAKE'  2850

# %%
df.loc[df['Comm'].isnull(),['Name','Sal']]
# Out:
#         Name   Sal
# 0    'SMITH'   800
# 1    'SCOTT'  3000
# 2   'MILLER'  1300
# 5     'KING'  5000
# 6    'CLARK'  2450
# 8    'JAMES'   950
# 10    'FORD'  3000
# 11   'ADAMS'  1100
# 12   'JONES'  2975
# 13   'BLAKE'  2850

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14 entries, 0 to 13
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   EmpNo   14 non-null     int64
#  1   Name    14 non-null     object
#  2   Job     14 non-null     object
#  3   MgrId   13 non-null     float64
#  4   DOJ     14 non-null     object
#  5   Sal     14 non-null     int64
#  6   Comm    4 non-null      float64
#  7   DeptNo  14 non-null     int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 1008.0+ bytes

# %%
df['Sal'] > 1000
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# Name: Sal, dtype: bool

# %%
df
# Out:
#     EmpNo      Name          Job   MgrId          DOJ   Sal    Comm  DeptNo
# 0    7369   'SMITH'      'CLERK'  7902.0  '17-DEC-80'   800     NaN      20
# 1    7788   'SCOTT'    'ANALYST'  7566.0  '09-DEC-82'  3000     NaN      20
# 2    7934  'MILLER'      'CLERK'  7782.0  '23-JAN-82'  1300     NaN      10
# 3    7654  'MARTIN'   'SALESMAN'  7698.0  '28-SEP-81'  1250  1400.0      30
# 4    7499   'ALLEN'   'SALESMAN'  7698.0  '20-FEB-81'  1600   300.0      30
# 5    7839    'KING'  'PRESIDENT'     NaN  '17-NOV-81'  5000     NaN      10
# 6    7782   'CLARK'    'MANAGER'  7839.0   '9-JUN-81'  2450     NaN      10
# 7    7844  'TURNER'   'SALESMAN'  7698.0   '8-SEP-81'  1500     0.0      30
# 8    7900   'JAMES'      'CLERK'  7698.0   '3-DEC-81'   950     NaN      30
# 9    7521    'WARD'   'SALESMAN'  7698.0  '22-FEB-81'  1250   500.0      30
# 10   7902    'FORD'    'ANALYST'  7566.0   '3-DEC-81'  3000     NaN      20
# ...

# %% [markdown]
# # str attribute

# %%
df['Name'] = df['Name'].str.replace("'","")
df['Job'] = df['Job'].str.replace("'","")
df['DOJ'] = df['DOJ'].str.replace("'","")

# %%
df
# Out:
#     EmpNo    Name        Job   MgrId        DOJ   Sal    Comm  DeptNo
# 0    7369   SMITH      CLERK  7902.0  17-DEC-80   800     NaN      20
# 1    7788   SCOTT    ANALYST  7566.0  09-DEC-82  3000     NaN      20
# 2    7934  MILLER      CLERK  7782.0  23-JAN-82  1300     NaN      10
# 3    7654  MARTIN   SALESMAN  7698.0  28-SEP-81  1250  1400.0      30
# 4    7499   ALLEN   SALESMAN  7698.0  20-FEB-81  1600   300.0      30
# 5    7839    KING  PRESIDENT     NaN  17-NOV-81  5000     NaN      10
# 6    7782   CLARK    MANAGER  7839.0   9-JUN-81  2450     NaN      10
# 7    7844  TURNER   SALESMAN  7698.0   8-SEP-81  1500     0.0      30
# 8    7900   JAMES      CLERK  7698.0   3-DEC-81   950     NaN      30
# 9    7521    WARD   SALESMAN  7698.0  22-FEB-81  1250   500.0      30
# 10   7902    FORD    ANALYST  7566.0   3-DEC-81  3000     NaN      20
# 11   7876   ADAMS      CLERK  7788.0  12-JAN-83  1100     NaN      20
# ...

# %%
 df['Sal'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Sal'].describe()
# Out:
# count      14.000000
# mean     2073.214286
# std      1182.503224
# min       800.000000
# 25%      1250.000000
# 50%      1550.000000
# 75%      2943.750000
# max      5000.000000
# Name: Sal, dtype: float64

# %%
df['Sal'] =df['Sal'].astype('float32')

# %%
df['Sal']
# Out:
# 0      800.0
# 1     3000.0
# 2     1300.0
# 3     1250.0
# 4     1600.0
# 5     5000.0
# 6     2450.0
# 7     1500.0
# 8      950.0
# 9     1250.0
# 10    3000.0
# 11    1100.0
# 12    2975.0
# 13    2850.0
# Name: Sal, dtype: float32

# %%
dept10 = df['DeptNo'] == 10
manager = df['Job'] == 'MANAGER'
df[dept10 & manager]
# Out:
#    EmpNo   Name      Job   MgrId       DOJ     Sal  Comm  DeptNo
# 6   7782  CLARK  MANAGER  7839.0  9-JUN-81  2450.0   NaN      10

# %%
df.to_csv("emp_clean.csv",index = False)

# %%
df['Comm'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3     False
# 4     False
# 5      True
# 6      True
# 7     False
# 8      True
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# Name: Comm, dtype: bool
